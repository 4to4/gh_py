# %% [markdown]
# ### Matplotlib tutorial ####

# %%
import matplotlib as mp

print(matplotlib.__version__)
# Out:
# 3.1.2

# %% [markdown]
# 1. how to check whic mode mpl is in ###

# %%
mp.is_interactive()
# Out:
# True

# %%
# Turn off interactive mode
mp.interactive(False)

# %%
import matplotlib.pyplot as pl
pl.plot([1,2,3], [2,3,4])

# %%
#backend that comes with jupyter note book
mp.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import matplotlib.pyplot as pl
matplotlib.use('Agg')
mp.interactive(True)
matplotlib.is_interactive()
# Out:
# True

# %%
pl.plot([1,2,3], [2,3,4])

# %%
import matplotlib
import matplotlib.pyplot as pl
import numpy as np

matplotlib.interactive(True)
pl.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
pl.plot([1,2,3,4,], [2,34,3,4], color='red')

# %%
pl.xlabel('x', fontsize=15, color='green')
pl.ylabel('x', fontsize=15, color='blue')
# Out:
# Text(0, 0.5, 'x')

# %%
# if only one list is passed then they are considered to be Y coordinates
pl.plot([1,2,3,3,4,5,])

# %%
x = np.linspace(start=0, stop=10, num=50)
pl.plot(x, np.sin(x))

# %%
#### importing data from pandas data frame to plot it ####

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as pl

# %%
data = pd.read_csv(r'D:/dev/large_dataset/datasets_mpl/exams.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
#triming the data frame to include only following columns
score = data[['math score', 'reading score', 'writing score' ]]
score
# Out:
#     math score  reading score  writing score
# 0           69             61             58
# 1           47             65             69
# 2           66             52             53
# 3           88             89             82
# 4           62             82             76
# ..         ...            ...            ...
# 95          56             59             61
# 96          64             57             62
# 97          62             48             38
# 98          44             34             36
# 99          48             48             40
#
# [100 rows x 3 columns]

# %%
# getting basic stats with .describe function
score.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
#convert dataframe to numpy array with np.array function
score_ar = np.array(score)

pl.plot(score)

# %%
bp = pl.boxplot(score)
